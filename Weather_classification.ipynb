# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Creating a dataframe of filenames and their labels

# %%
filenames = os.listdir(r"D:\weather\train")
categories = []
for filename in filenames:
    if filename.startswith('cloudy'):
        categories.append('cloudy')
    elif filename.startswith('rain'):
        categories.append('rain')
    elif filename.startswith('shine'):
        categories.append('shine')
    elif filename.startswith('sunrise'):
        categories.append('sunrise')

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#         filename category
# 0    cloudy1.jpg   cloudy
# 1   cloudy10.jpg   cloudy
# 2  cloudy100.jpg   cloudy
# 3  cloudy101.jpg   cloudy
# 4  cloudy102.jpg   cloudy

# %%
df['category'].value_counts()
# Out:
# sunrise    347
# cloudy     290
# shine      243
# rain       207
# Name: category, dtype: int64

# %% [markdown]
# ## Shuffling Data

# %%
df = shuffle(df, random_state = 25)

# %% [markdown]
# ## Data Augmentation using the ImageDataGenerator class

# %%
image_shape = (128, 128, 3)
batch_size = 18

# %% [markdown]
# ### For training data

# %%
train_datagen = ImageDataGenerator(
                                   rescale = 1./255,
                                   rotation_range = 15,
                                   shear_range = 0.1,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   validation_split = 0.20
                                   )

train_generator = train_datagen.flow_from_dataframe(
                                                    df, 
                                                    r"D:\weather\train", 
                                                    x_col = 'filename',
                                                    y_col = 'category',
                                                    target_size = image_shape[:2],
                                                    class_mode = 'categorical',
                                                    batch_size = batch_size,
                                                    validate_filenames = False,
                                                    subset = 'training'
                                                    )
# Out:
# Found 870 non-validated image filenames belonging to 4 classes.

# %% [markdown]
# ### For validation data

# %%
validation_generator = train_datagen.flow_from_dataframe(
                                                         df, 
                                                         r"D:\weather\train", 
                                                         x_col = 'filename',
                                                         y_col = 'category',
                                                         target_size = image_shape[:2],
                                                         class_mode = 'categorical',
                                                         batch_size = batch_size,
                                                         validate_filenames = False,
                                                         subset = 'validation'
                                                         )
# Out:
# Found 217 non-validated image filenames belonging to 4 classes.

# %% [markdown]
# ### creating an example case to see how it's working

# %%
example_df = df.sample(n = 1).reset_index(drop = True)
example_generator = train_datagen.flow_from_dataframe(
                                                      example_df, 
                                                      r"D:\weather\train", 
                                                      x_col = 'filename',
                                                      y_col = 'category',
                                                      target_size = image_shape[:2],
                                                      class_mode = 'categorical',
                                                      validate_filenames = False
                                                      )
# Out:
# Found 1 non-validated image filenames belonging to 1 classes.

# %% [markdown]
# ### Taking a look at how the example generator is working

# %%
plt.figure(figsize = (12, 12))
for i in range(0, 12):
    plt.subplot(4, 3, i + 1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Since the Data augmentation is producing results as expected we can define our model now

# %% [markdown]
# ### A typical CNN model with 3 convolutional layers and an output layer

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(16, (3, 3), activation = 'relu', input_shape = image_shape))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(4, activation = 'softmax')) # 4 because we have four classes (cloudy, rain, shine and sunrise)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['categorical_accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 126, 126, 16)      448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 126, 126, 16)      64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 61, 61, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 61, 61, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                921632
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 927,172
# Trainable params: 927,012
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### using early stopping to stop our model from training if it stops improving

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience = 20)

# %% [markdown]
# ### Auto adjusts our learning rate based on the monitor parameter ("validation_loss" in this case)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                            patience = 4, 
                                            verbose = 1, 
                                            factor = 0.1, 
                                            min_lr = 0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ## Fitting the data into our model

# %%
epochs = 50
history = model.fit_generator(
                              train_generator, 
                              epochs = epochs,
                              validation_data = validation_generator,
                              validation_steps = validation_generator.samples // batch_size,
                              steps_per_epoch = train_generator.samples // batch_size,
                              callbacks = callbacks
                              )
# Out:
# Epoch 1/50
# 48/48 [==============================] - 15s 306ms/step - loss: 0.8349 - categorical_accuracy: 0.7002 - val_loss: 1.1804 - val_categorical_accuracy: 0.2870
# Epoch 2/50
# 48/48 [==============================] - 17s 350ms/step - loss: 0.5351 - categorical_accuracy: 0.8083 - val_loss: 2.2764 - val_categorical_accuracy: 0.3065
# Epoch 3/50
# 48/48 [==============================] - 15s 311ms/step - loss: 0.5531 - categorical_accuracy: 0.8134 - val_loss: 2.3905 - val_categorical_accuracy: 0.2864
# Epoch 4/50
# 48/48 [==============================] - 14s 296ms/step - loss: 0.6339 - categorical_accuracy: 0.7688 - val_loss: 2.2341 - val_categorical_accuracy: 0.2864
# Epoch 5/50
# 48/48 [==============================] - 13s 271ms/step - loss: 0.5177 - categorical_accuracy: 0.8157 - val_loss: 1.7005 - val_categorical_accuracy: 0.3015
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 6/50
# 48/48 [==============================] - 13s 272ms/step - loss: 0.4650 - categorical_accuracy: 0.8333 - val_loss: 1.8674 - val_categorical_accuracy: 0.2965
# Epoch 7/50
# 48/48 [==============================] - 13s 278ms/step - loss: 0.4369 - categorical_accuracy: 0.8533 - val_loss: 1.1720 - val_categorical_accuracy: 0.3015
# Epoch 8/50
# 48/48 [==============================] - 13s 262ms/step - loss: 0.4274 - categorical_accuracy: 0.8509 - val_loss: 0.8964 - val_categorical_accuracy: 0.4121
# Epoch 9/50
# 48/48 [==============================] - 13s 277ms/step - loss: 0.3996 - categorical_accuracy: 0.8486 - val_loss: 1.2712 - val_categorical_accuracy: 0.4523
# Epoch 10/50
# 48/48 [==============================] - 12s 255ms/step - loss: 0.3998 - categorical_accuracy: 0.8615 - val_loss: 0.8225 - val_categorical_accuracy: 0.5678
# Epoch 11/50
# 48/48 [==============================] - 15s 316ms/step - loss: 0.4115 - categorical_accuracy: 0.8697 - val_loss: 0.9339 - val_categorical_accuracy: 0.6683
# Epoch 12/50
# 48/48 [==============================] - 16s 331ms/step - loss: 0.3722 - categorical_accuracy: 0.8732 - val_loss: 0.7535 - val_categorical_accuracy: 0.7085
# Epoch 13/50
# 48/48 [==============================] - 14s 296ms/step - loss: 0.3675 - categorical_accuracy: 0.8850 - val_loss: 2.8677 - val_categorical_accuracy: 0.7839
# Epoch 14/50
# 48/48 [==============================] - 13s 263ms/step - loss: 0.4125 - categorical_accuracy: 0.8588 - val_loss: 0.3434 - val_categorical_accuracy: 0.8009
# Epoch 15/50
# 48/48 [==============================] - 13s 267ms/step - loss: 0.3627 - categorical_accuracy: 0.8762 - val_loss: 0.3661 - val_categorical_accuracy: 0.8191
# Epoch 16/50
# 48/48 [==============================] - 12s 247ms/step - loss: 0.3928 - categorical_accuracy: 0.8627 - val_loss: 0.2228 - val_categorical_accuracy: 0.8392
# Epoch 17/50
# 48/48 [==============================] - 12s 240ms/step - loss: 0.3455 - categorical_accuracy: 0.8738 - val_loss: 0.3613 - val_categorical_accuracy: 0.8643
# Epoch 18/50
# 48/48 [==============================] - 14s 301ms/step - loss: 0.3577 - categorical_accuracy: 0.8774 - val_loss: 0.4215 - val_categorical_accuracy: 0.8593
# Epoch 19/50
# 48/48 [==============================] - 14s 289ms/step - loss: 0.3501 - categorical_accuracy: 0.8831 - val_loss: 0.4259 - val_categorical_accuracy: 0.8794
# Epoch 20/50
# 48/48 [==============================] - 13s 271ms/step - loss: 0.3639 - categorical_accuracy: 0.8702 - val_loss: 0.1824 - val_categorical_accuracy: 0.8643
# Epoch 21/50
# 48/48 [==============================] - 13s 267ms/step - loss: 0.3038 - categorical_accuracy: 0.9062 - val_loss: 0.2466 - val_categorical_accuracy: 0.8593
# Epoch 22/50
# 48/48 [==============================] - 12s 252ms/step - loss: 0.3354 - categorical_accuracy: 0.8862 - val_loss: 0.8981 - val_categorical_accuracy: 0.7990
# Epoch 23/50
# 48/48 [==============================] - 13s 269ms/step - loss: 0.3460 - categorical_accuracy: 0.8869 - val_loss: 0.4203 - val_categorical_accuracy: 0.9095
# Epoch 24/50
# 48/48 [==============================] - 11s 239ms/step - loss: 0.3330 - categorical_accuracy: 0.8935 - val_loss: 0.4595 - val_categorical_accuracy: 0.8593
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 25/50
# 48/48 [==============================] - 12s 243ms/step - loss: 0.3051 - categorical_accuracy: 0.8976 - val_loss: 0.4097 - val_categorical_accuracy: 0.8744
# Epoch 26/50
# 48/48 [==============================] - 11s 233ms/step - loss: 0.3321 - categorical_accuracy: 0.8831 - val_loss: 0.0239 - val_categorical_accuracy: 0.8643
# Epoch 27/50
# 48/48 [==============================] - 12s 249ms/step - loss: 0.2937 - categorical_accuracy: 0.9026 - val_loss: 0.3434 - val_categorical_accuracy: 0.8565
# Epoch 28/50
# 48/48 [==============================] - 13s 261ms/step - loss: 0.3570 - categorical_accuracy: 0.8779 - val_loss: 0.5889 - val_categorical_accuracy: 0.8844
# Epoch 29/50
# 48/48 [==============================] - 12s 248ms/step - loss: 0.3278 - categorical_accuracy: 0.8885 - val_loss: 0.2641 - val_categorical_accuracy: 0.8844
# Epoch 30/50
# 48/48 [==============================] - 11s 238ms/step - loss: 0.3559 - categorical_accuracy: 0.8650 - val_loss: 0.4822 - val_categorical_accuracy: 0.8442
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 31/50
# 48/48 [==============================] - 11s 240ms/step - loss: 0.3377 - categorical_accuracy: 0.8803 - val_loss: 0.6501 - val_categorical_accuracy: 0.8744
# Epoch 32/50
# 48/48 [==============================] - 12s 242ms/step - loss: 0.3326 - categorical_accuracy: 0.8897 - val_loss: 0.4073 - val_categorical_accuracy: 0.8945
# Epoch 33/50
# 48/48 [==============================] - 11s 236ms/step - loss: 0.2843 - categorical_accuracy: 0.9014 - val_loss: 0.2515 - val_categorical_accuracy: 0.8492
# Epoch 34/50
# 48/48 [==============================] - 13s 281ms/step - loss: 0.3527 - categorical_accuracy: 0.8803 - val_loss: 0.4232 - val_categorical_accuracy: 0.8693
# Epoch 35/50
# 48/48 [==============================] - 12s 241ms/step - loss: 0.3277 - categorical_accuracy: 0.8893 - val_loss: 0.4582 - val_categorical_accuracy: 0.8744
# Epoch 36/50
# 48/48 [==============================] - 12s 240ms/step - loss: 0.3135 - categorical_accuracy: 0.8843 - val_loss: 0.2773 - val_categorical_accuracy: 0.8744
# Epoch 37/50
# 48/48 [==============================] - 12s 243ms/step - loss: 0.3180 - categorical_accuracy: 0.8873 - val_loss: 0.1804 - val_categorical_accuracy: 0.8945
# Epoch 38/50
# 48/48 [==============================] - 11s 238ms/step - loss: 0.3333 - categorical_accuracy: 0.8955 - val_loss: 0.2922 - val_categorical_accuracy: 0.8844
# Epoch 39/50
# 48/48 [==============================] - 11s 233ms/step - loss: 0.3102 - categorical_accuracy: 0.8988 - val_loss: 0.0550 - val_categorical_accuracy: 0.8794
# Epoch 40/50
# 48/48 [==============================] - 12s 247ms/step - loss: 0.3258 - categorical_accuracy: 0.8912 - val_loss: 0.2687 - val_categorical_accuracy: 0.8750
# Epoch 41/50
# 48/48 [==============================] - 13s 277ms/step - loss: 0.3556 - categorical_accuracy: 0.8850 - val_loss: 0.3635 - val_categorical_accuracy: 0.8693
# Epoch 42/50
# 48/48 [==============================] - 11s 222ms/step - loss: 0.3141 - categorical_accuracy: 0.8838 - val_loss: 0.7184 - val_categorical_accuracy: 0.8492
# Epoch 43/50
# 48/48 [==============================] - 11s 235ms/step - loss: 0.2851 - categorical_accuracy: 0.8991 - val_loss: 0.2681 - val_categorical_accuracy: 0.8643
# Epoch 44/50
# 48/48 [==============================] - 11s 227ms/step - loss: 0.3135 - categorical_accuracy: 0.8838 - val_loss: 0.5164 - val_categorical_accuracy: 0.9045
# Epoch 45/50
# 48/48 [==============================] - 11s 236ms/step - loss: 0.3190 - categorical_accuracy: 0.8850 - val_loss: 0.3531 - val_categorical_accuracy: 0.8744
# Epoch 46/50
# 48/48 [==============================] - 10s 218ms/step - loss: 0.3460 - categorical_accuracy: 0.8779 - val_loss: 0.3862 - val_categorical_accuracy: 0.8442

# %% [markdown]
# ## Plotting the accuracy and loss rates

# %%
plt.style.use('tableau-colorblind10')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 12))
ax1.plot(history.history['loss'], color = 'b', label = "Training loss")
ax1.plot(history.history['val_loss'], color = 'r', label = "validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 10, 1))

ax1.legend(loc = 'best', shadow = True)

ax2.plot(history.history['categorical_accuracy'], color = 'b', label = "Training accuracy")
ax2.plot(history.history['val_categorical_accuracy'], color = 'r',label = "Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

ax2.legend(loc = 'best', shadow = True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Creating the test Dataframe

# %%
test_filenames = os.listdir(r"D:\weather\test")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_generator = test_datagen.flow_from_dataframe(
                                              test_df, 
                                              r"D:\weather\test", 
                                              x_col = 'filename',
                                              y_col = None,
                                              class_mode = None,
                                              target_size =  image_shape[:2],
                                              batch_size = batch_size,
                                              shuffle = False,
                                              validate_filenames = False
                                              )
# Out:
# Found 38 non-validated image filenames.

# %% [markdown]
# ## Start predicting using our model

# %%
predict = model.predict_generator(test_generator, steps = np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis = -1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'].value_counts()
# Out:
# cloudy     11
# sunrise    11
# rain        9
# shine       7
# Name: category, dtype: int64

# %% [markdown]
# ## Displaying our predictions

# %%
plt.style.use('classic')
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img(r"D:\weather\test" + "\\"+ filename, target_size = image_shape[:2])
    plt.subplot(6, 3, index + 1)
    plt.imshow(img)
    plt.xlabel(filename + '\nPrediction: ' + "{}".format(category) )
plt.tight_layout()
plt.show()
